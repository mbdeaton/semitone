# %% [markdown]
# # Demos of semitone package
#
# Brett Deaton -- Spring 2024

# %%
import semitone as st

# %%
fig = st.SpiralPlot.draw(
    (
        # st.Chromatic("C"),
        st.Major("C"),
        st.Major("D"),
        # st.DiatonicMode("C", 6),
        # st.Minor("C"),
    ),
    octaves_above=2,
    octaves_below=0,
)
fig.write_image("test.png")
fig.show()
